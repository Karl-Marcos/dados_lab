# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
config = {'axes.spines.right': False,
    'axes.spines.top': False,
    'axes.edgecolor': '.4',
    'axes.labelcolor': '.0',
    'axes.titlesize': 'large',
    'axes.labelsize': 'medium',
    'figure.autolayout': True,
    'figure.figsize': (4.5, 3.5),
    'font.family': ['serif'],
    'font.size': 10.0,
    'grid.linestyle': '--',
    'legend.facecolor': '.9',
    'legend.frameon': True,
    'savefig.transparent': True,
    'text.color': '.0',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small'}

# %%
dados = pd.read_excel(r'dados_bruto\FTIR_BIM.xlsx')
x44 = dados['x44']
y44 = dados['y44']
x62 = dados['x62']
y62 = dados['y62']

# %%
plt.style.use(['seaborn-whitegrid', 'seaborn-paper', 'seaborn-muted', config])

fig, ax = plt.subplots(1,1)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)


ax.plot(x44, y44, c = 'g')
ax.set_xlabel('Número de onda ($cm^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 44')
ax.invert_xaxis()

plt.savefig(r'graficos\AM_44_FTIR_BIM.png', dpi = 200)

# %%
plt.style.use(['seaborn-whitegrid', 'seaborn-paper', 'seaborn-muted', config])

fig, ax = plt.subplots(1,1)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)


ax.plot(x62, y62, c = 'r')
ax.set_xlabel('Número de onda ($cm^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 62')
ax.invert_xaxis()

plt.savefig(r'graficos\AM_62_FTIR_BIM.png', dpi = 200)

# %% [markdown]
# # Isadora e Marcos 09/05

# %%
POV_2_1 = pd.read_csv(r'dados_bruto/POV_2_1.txt', sep="\t")
POV_2_AMO_1 = pd.read_csv(r'dados_bruto/POV_2_AMO_1.txt', sep="\t")
POV_2_DIA_1 = pd.read_csv(r'dados_bruto/POV_2_DIA_1.txt', sep="\t")
POV_4_1 = pd.read_csv(r'dados_bruto/POV_4_1.txt', sep="\t")
POV_4_AMO_1 = pd.read_csv(r'dados_bruto/POV_4_AMO_1.txt', sep="\t")
POV_4_DIA_1 = pd.read_csv(r'dados_bruto/POV_4_DIA_1.txt', sep="\t")

# %%
x = [i[0] for i in POV_2_1.values]
T = [i[1] for i in POV_2_1.values]
fig, ax = plt.subplots(1,1)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.plot(x,T)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 2')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_2_1_FTIR.png', dpi = 200)

# %%
x = [i[0] for i in POV_2_AMO_1.values]
T = [i[1] for i in POV_2_AMO_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x,T)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 2 após "Salting"')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_2_AMO_1_FTIR.png', dpi = 200)

# %%
x = [i[0] for i in POV_2_DIA_1.values]
T = [i[1] for i in POV_2_DIA_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x,T)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 2')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_2_DIA_1_FTIR.png', dpi = 200)

# %%
x1 = [i[0] for i in POV_2_1.values]
T1 = [i[1] for i in POV_2_1.values]
x2 = [i[0] for i in POV_2_AMO_1.values]
T2 = [i[1] for i in POV_2_AMO_1.values]
x3 = [i[0] for i in POV_2_DIA_1.values]
T3 = [i[1] for i in POV_2_DIA_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x1,T1, label = 'Centrifugada')
ax.plot(x2,T2, label = 'Salting')
ax.plot(x3,T3, label = 'Diálise')
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 2 após diálise')
ax.invert_xaxis()
ax.legend()

plt.savefig(r'graficos\POV_2_comp_FTIR.png', dpi = 200)

# %%
x = [i[0] for i in POV_4_1.values]
T = [i[1] for i in POV_4_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x,T)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 4')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_4_1_FTIR.png', dpi = 200)

# %%
x = [i[0] for i in POV_4_AMO_1.values]
T = [i[1] for i in POV_4_AMO_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x,T)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 4 após "Salting"')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_4_AMO_1_FTIR.png', dpi = 200)

# %%
x = [i[0] for i in POV_4_DIA_1.values]
T = [i[1] for i in POV_4_DIA_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x,T)
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 4 após diálise')
ax.invert_xaxis()

plt.savefig(r'graficos\POV_4_DIA_1_FTIR.png', dpi = 200)

# %%
x1 = [i[0] for i in POV_4_1.values]
T1 = [i[1] for i in POV_4_1.values]
x2 = [i[0] for i in POV_4_AMO_1.values]
T2 = [i[1] for i in POV_4_AMO_1.values]
x3 = [i[0] for i in POV_4_DIA_1.values]
T3 = [i[1] for i in POV_4_DIA_1.values]
fig, ax = plt.subplots(1,1)
ax.plot(x1,T1, label = 'Centrifugada')
ax.plot(x2,T2, label = 'Salting')
ax.plot(x3,T3, label = 'Diálise')
ax.tick_params(direction='in', which='both',top=True,right=True,labelsize=12)
ax.set_xlabel(r'Número de onda (cm$^{-1}$)')
ax.set_ylabel('Transmitância (%)')
ax.set_title('Espectro FTIR da Amostra 4')
ax.invert_xaxis()
ax.legend()

plt.savefig(r'graficos\POV_4_comp_FTIR.png', dpi = 200)
